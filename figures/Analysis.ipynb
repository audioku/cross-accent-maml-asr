epochs_valid = [i for i in range(1, len(aishell_valid_losses)+1)]

epochs_r_50_train = [i for i in range(1, len(aishell_r_50_train_losses)+1)]
epochs_r_50_valid = [i for i in range(1, len(aishell_r_50_valid_losses)+1)]

epochs_r_75_train = [i for i in range(1, len(aishell_r_75_train_losses)+1)]
epochs_r_75_valid = [i for i in range(1, len(aishell_r_75_valid_losses)+1)]

epochs_r_100_train = [i for i in range(1, len(aishell_r_100_train_losses)+1)]
epochs_r_100_valid = [i for i in range(1, len(aishell_r_100_valid_losses)+1)]

epochs_baseline_r_50_train = [i for i in range(1, len(aishell_baseline_r_50_train_losses)+1)]
epochs_baseline_r_50_valid = [i for i in range(1, len(aishell_baseline_r_50_valid_losses)+1)]

epochs_baseline_r_100_train = [i for i in range(1, len(aishell_baseline_r_100_train_losses)+1)]
epochs_baseline_r_100_valid = [i for i in range(1, len(aishell_baseline_r_100_valid_losses)+1)]


print(len(aishell_train_losses))
print(len(aishell_valid_losses))
print(len(epochs_train))
print(len(epochs_valid))

t_train_df = pd.DataFrame({'train': aishell_train_losses[:45],
                    'epochs_train': epochs_train[:45]})

t_valid_df = pd.DataFrame({'valid': aishell_valid_losses[:45],
                    'epochs_valid': epochs_valid[:45]
                    })

t_r_50_train_df = pd.DataFrame({'train': aishell_r_50_train_losses[:45],
                    'epochs_train': epochs_r_50_train[:45]})

t_r_50_valid_df = pd.DataFrame({'valid': aishell_r_50_valid_losses[:45],
                    'epochs_valid': epochs_r_50_valid[:45]
                    })
t_r_75_train_df = pd.DataFrame({'train': aishell_r_75_train_losses[:45],
                    'epochs_train': epochs_r_75_train[:45]})
                          
t_r_75_valid_df = pd.DataFrame({'valid': aishell_r_75_valid_losses[:45],
                    'epochs_valid': epochs_r_75_valid[:45]
                    })
                    
t_r_100_train_df = pd.DataFrame({'train': aishell_r_100_train_losses[:45],
                    'epochs_train': epochs_r_100_train[:45]})

t_r_100_valid_df = pd.DataFrame({'valid': aishell_r_100_valid_losses[:45],
                    'epochs_valid': epochs_r_100_valid[:45]
                    })

t_baseline_r_50_train_df = pd.DataFrame({'train': aishell_baseline_r_50_train_losses[:45],
                    'epochs_train': epochs_baseline_r_50_train[:45]})

t_baseline_r_50_valid_df = pd.DataFrame({'valid': aishell_baseline_r_50_valid_losses[:45],
                    'epochs_valid': epochs_baseline_r_50_valid[:45]
                    })

t_baseline_r_100_train_df = pd.DataFrame({'train': aishell_baseline_r_100_train_losses[:45],
                    'epochs_train': epochs_baseline_r_100_train[:45]})

t_baseline_r_100_valid_df = pd.DataFrame({'valid': aishell_baseline_r_100_valid_losses[:45],
                    'epochs_valid': epochs_baseline_r_100_valid[:45]
                    })

fig = plt.figure(figsize=(4,1.8))

# multiple line plot
plt.plot( 'epochs_train', 'train', linestyle='-', label=r'$LRT(r=50)$', data=t_r_50_train_df, color='dodgerblue', linewidth=1, alpha=0.8)
# plt.plot( 'epochs_train', 'train', marker='',markersize=1, linestyle='-', label=r'$LRT($r=75$)$', data=t_r_75_train_df, color='darkorange', linewidth=1, alpha=0.8)
plt.plot( 'epochs_train', 'train', linestyle='-', label=r'$LRT(r=100$)', data=t_r_100_train_df, color='forestgreen', linewidth=1, alpha=0.8)
# plt.plot( 'epochs_train', 'train', linestyle='--', label=r'$Transformer (large)$', data=t_train_df, color='black', linewidth=0.8, alpha=0.6)
plt.plot( 'epochs_train', 'train', linestyle='--', label=r'$Transformer (medium)$', data=t_baseline_r_100_train_df, color='red', linewidth=0.8, alpha=0.8)
plt.plot( 'epochs_train', 'train', linestyle=':', label=r'$Transformer (small)$', data=t_baseline_r_50_train_df, color='dimgray', linewidth=0.8, alpha=0.8)

plt.title(r'Training loss', fontsize=9)
plt.ylabel(r'$loss$', fontsize=8)
plt.xlabel(r'$epoch$', fontsize=8)

# plt.yticks(np.arange(0.5, 3, 0.5))
plt.tick_params(axis="x", labelsize=7)
plt.tick_params(axis="y", labelsize=7)

plt.grid()
plt.legend(loc='center right', bbox_to_anchor=(1,0.61), prop={'size': 6})
plt.savefig("train_loss.pdf", bbox_inches='tight')
# Out:
# 46
# 46
# 46
# 46

# %%
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(4,1.8))

plt.plot( 'epochs_valid', 'valid', linestyle='-', label=r'$LRT(r=50)$', data=t_r_50_valid_df, color='dodgerblue', linewidth=0.8)
# plt.plot( 'epochs_valid', 'valid', linestyle='-', label=r'$LRT(r=75)$', data=t_r_75_valid_df, color='orange', linewidth=0.8)
plt.plot( 'epochs_valid', 'valid', linestyle='-', label=r'$LRT(r=100)$', data=t_r_100_valid_df, color='forestgreen', linewidth=0.8)
# plt.plot( 'epochs_valid', 'valid', linestyle='--', label=r'$Transformer (large)$', data=t_valid_df, color='black', linewidth=0.8, alpha=0.6)
plt.plot( 'epochs_valid', 'valid', linestyle='--', label=r'$Transformer (medium)$', data=t_baseline_r_100_valid_df, color='red', linewidth=0.8)
plt.plot( 'epochs_valid', 'valid', linestyle=':', label=r'$Transformer (small)$', data=t_baseline_r_50_valid_df, color='dimgray', linewidth=0.8)

# plt.title(r'Valid loss', fontsize=9)
plt.ylabel(r'$loss$', fontsize=8)
plt.xlabel(r'$epoch$', fontsize=8)
# plt.yticks(np.arange(0.1, 2, 0.1))

plt.tick_params(axis="x", labelsize=7)
plt.tick_params(axis="y", labelsize=7)

plt.grid()
plt.legend(loc='center right', bbox_to_anchor=(1,0.61), prop={'size': 6})
plt.savefig("valid_loss.pdf", bbox_inches='tight')

# %%
# x1, x2, y1, y2 = -1.5, -0.9, -2.5, -1.9

# axins = plt.inset_axes([0.5, 0.5, 0.47, 0.47])
# axins.imshow(Z2, extent=extent, interpolation="nearest",
#           origin="lower")

# axins.set_xlim(x1, x2)
# axins.set_ylim(y1, y2)
# axins.set_xticklabels('')
# axins.set_yticklabels('')

# plt.indicate_inset_zoom(axins)

plt.show()
